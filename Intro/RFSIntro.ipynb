# %% [markdown]
# # Välkommna till Rymdforskarskolans programerings intro!!!
#
# Här ska ni få lära er lite om hur programeringspråket python fungerar och hur jupyter notebooks fungerar. Det ni tittar på just nu är en jupyter note
# book. Det är ett sätt att skriva och köra kod och det är det vi kommer använda under hela rymdforskarskolans gång för den mesta programeringen.
#
# I jupyter finns det olika sorters block. Detta är ett text block här kan man skriva saker.

# %%
# Detta är ett kodblock här kan man skriva och köra kod

print('Hur taggade är ni på rymdforskarskolan?')
# Out:
# Hur taggade är ni på rymdforskarskolan?

# %% [markdown]
# För att kunna köra koden ovan så trycker man på kanppen som ser ut som en play knapp uppe bland verktygen i vänster hörn eller så trycker man shift+enter. Under rymdforskarskolans gång så kommer vi anväda oss av detta verktyget för att lära er att göra  en hel massa coola grejer. Så när ni är klara med rymdforskarskolan så kommer ni kunna göra saker som:

# %% [markdown]
# ## Plotta coola grafer

# %%
import numpy as np
from matplotlib import pyplot as plt
from astropy.io import fits

cooldata = fits.open('hst_05240_08_wfpc2_f336w_pc_drz.fits')

plt.imshow(cooldata[1].data, cmap='gray')
plt.show()
