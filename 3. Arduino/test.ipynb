# %%
# %%sh
# cat run.sh
# bash run.sh
# Out:
# #!/bin/bash
# git clone https://github.com/adafruit/circuitpython_kernel.git
# cd circuitpython_kernel/
# python3 setup.py install
# fatal: destination path 'circuitpython_kernel' already exists and is not an empty directory.
# python3 -m circuitpython_kernel.installrunning install
# /home/antonlindbro/Code/RFS/.venv/lib/python3.10/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# ...
